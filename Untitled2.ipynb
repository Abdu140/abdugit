# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdu140/abdugit/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("abdualghnee Al-molike")
# Out:
# abdualghnee Al-molike

# %%
x=5
y=8
u=x+y
print(u)
# Out:
# 13

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
# 'Colab Notebooks'  'Google AI Studio'
